# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Opening and Reading Files
#
# So far we've discussed how to open files manually, one by one. Let's explore how we can open files programatically.

# %% [markdown]
# _____

# %% [markdown]
# ### Review: Understanding File Paths

# %%
pwd
# Out:
# '/Users/mitul/Downloads/Complete-Python-3-Bootcamp-master/12-Advanced Python Modules'

# %% [markdown]
# ### Create Practice File
#
# We will begin by creating a practice text file that we will be using for demonstration.

# %%
f = open('practice.txt','w+')

# %%
f.write('test')
f.close()

# %% [markdown]
# ### Getting Directories
#
# Python has a built-in [os module](https://docs.python.org/3/library/os.html) that allows us to use operating system dependent functionality.
#
# You can get the current directory:

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/mitul/Downloads/Complete-Python-3-Bootcamp-master/12-Advanced Python Modules'

# %% [markdown]
# ### Listing Files in a Directory
#
# You can also use the os module to list directories.

# %%
# In your current directory
os.listdir()
# Out:
# ['Example_Top_Level',
#  '08-Advanced-Python-Module-Exercise',
#  'practice.txt',
#  '00-Collections-Module.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '02-Datetime-Module.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '.ipynb_checkpoints',
#  '04-Python Debugger (pdb).ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb']

# %%
# In any directory you pass
os.listdir("/Users/mitul/Downloads")
# Out:
# ['02. Simple-minimize-functions (1).pptx',
#  'For research - Google Sheets_files',
#  '1332278.jpeg',
#  'Series',
#  'pxfuel (1).jpg',
#  'download.jpeg',
#  'Artificial Intelligence–Grounded Fake News Sensor.pptx',
#  'DLD cover page .pdf',
#  'Discrete and Continuous Random variable _compressed (2).pdf',
#  'Music',
#  'Math books',
#  '~$ectronics Lab.docx',
#  '08 Strings.pdf',
#  'PikPak_Mac_AppleSilicon.dmg',
#  'SSNI-558-en.srt',
#  '0112410205_Mahmudul Hassan .pdf',
#  'wallpaperflare.com_wallpaper.jpg',
#  'wallpaperflare.com_wallpaper (5).jpg',
#  'Movie',
#  '491511585_29104030089240945_1089342464866340327_n (1).mp4',
#  'WhatsApp Video 2025-03-08 at 00.21.37.mp4',
#  '500183654_4106736929614942_3453245739905486993_n.jpg',
#  'Hostel of CS Dons - Google Sheets_files',
#  '06-file.pptx.pdf',
#  'OOP-Final-242.pdf',
#  'Problemset',
#  'Problemsolve Technique',
#  'Instructions.pdf',
#  'ananta.jpeg',
#  'WhatsApp Image 2025-06-25 at 11.04.49 (1).jpeg',
#  '.DS_Store',
#  'question.pdf',
#  'Mahmudul Hassan(0112410205) CV Resume.pdf',
#  'fcdbf9de-79e4-4e1f-9e6c-bf2cc3ee5682.jpg',
#  'wallpaperflare.com_wallpaper (4).jpg',
#  'oop lab inheritance_polymorphism.pdf',
#  'cl4 3.xcodeproj',
#  'WhatsApp Image 2025-06-25 at 11.04.49.jpeg',
#  'Lab 7.zip',
#  'pxfuel.jpg',
#  'EEE-2124 Cover Page.docx',
#  '~$ectronics Lab report -1.docx',
#  'Final_Exam_Question_241_CSE1111_C_SAhSh.pdf',
#  'Final_2_Page_Waste_Management_Assignment.docx',
#  'CSE 124_Draft Lab Manual.pdf',
#  'WhatsApp Image 2024-11-24 at 14.57.18 (1).jpeg',
#  'Pdf ',
#  '.localized',
#  'Electronics Lab report -1.docx',
#  'FSDSS-672.V2.en-en.srt',
#  'Chief.of.War.S01E04.1080p.10bit.WEBRip.6CH.x265.HEVC-PSA.mkv',
#  '7288FA97-7B3C-456B-BA0A-15724EAF1D9F.png',
#  'OOp Assignment.pdf',
#  '491532005_23869488555992350_2728989471790767108_n.mp4',
#  'Screenshot_20250314-170610_Facebook.jpg',
#  'Chief.of.War.S01E03.1080p.10bit.WEBRip.6CH.x265.HEVC-PSA.mkv',
#  'WhatsApp Image 2024-12-12 at 11.03.40 (1).jpeg',
#  'Untitled document.docx',
#  'Electric.pdf',
#  '491172357_29050662614577954_6768967658363416442_n.mp4',
#  'chaad.jpeg',
#  'Spring24_CSE1115_OOP_MidtermQuestion.pdf',
#  'dsa.jpeg',
#  'CSE 1326 Exp 1.pptx',
#  ' Stats Lecture_Note_Upto_Eid_Vacation.pdf',
#  'ProblemSet Fucntion and String.zip',
#  'CSE 1326 Exp 2 (1).pptx',
#  'DSA-I Assignment.pdf',
#  '09 Function.pdf',
#  'Build System.txt',
#  'NIMA-035 Mina Kitano.en.whisperjav-en.srt',
#  'WhatsApp Image 2025-06-25 at 16.33.08.jpeg',
#  'img.png',
#  'CS Dons.xlsx',
#  'WhatsApp Image 2025-06-16 at 19.29.21.jpeg',
#  '03-counting.pptx',
#  '04-pointer.pptx.pdf',
#  'cl4 2.xcodeproj',
#  'SpotifyInstaller.zip',
#  'Assignment',
#  'EC Assignment .pdf',
#  '490717182_9422182117851050_1150948909292370244_n.mp4',
#  '68346F31-05AA-4316-830D-73B57552C331.mp4',
#  '0112410205 (2).pdf',
#  'AI assists in autonomous space missions and planetary exploration. AI-driven simulations for interstellar travel and exoplanet discovery..pdf',
#  'DBMS project.pdf',
#  'wallpaperflare.com_wallpaper (2).jpg',
#  '491508554_9280822448692891_8422459880286702736_n.mp4',
#  'MId assignment',
#  'CSE 1111 SAhSh E.pdf',
#  'Software and app',
#  'Spring24_CSE1115_OOP_FinalQues1.pdf',
#  'CT on GUI.pdf',
#  'Complete-Python-3-Bootcamp-master',
#  'WhatsApp Image 2025-06-26 at 23.51.42.jpeg',
#  '2048.webp',
#  'Lab Report Materials',
#  'Hostel of CS Dons - Google Sheets.html',
#  'Solution_Manual_Fundamentals_of_Electric.pdf',
#  '0112410205 (1).pdf',
#  'WhatsApp Image 2024-11-24 at 14.57.18.jpeg',
#  '8921371.jpg',
#  'wallpaperflare.com_wallpaper (1).jpg',
#  'English Instrument',
#  'cl4.xcodeproj.zip',
#  '0112410205.pdf',
#  '~$titled document.docx',
#  'vid_720p (3).mp4',
#  '~$D lab reoirt Register.docx',
#  'DSA_1_ProblemSet_LinkedList.pdf',
#  'Meal_Count_July_2025.xlsx',
#  'MXPlayer',
#  '01. Logic-gates (1).pptx',
#  '491052295_24077229358546749_6037772021452456212_n.mp4',
#  'FINAL Term-20250626',
#  'WhatsApp Image 2024-12-12 at 11.03.40.jpeg',
#  'CamScanner 12-08-2024 23.48.pdf',
#  'OOP-Mid-Summer-2024.pdf',
#  'cl4.xcodeproj',
#  '491470594_9335688599863560_3746675455922020685_n.mp4',
#  'Assignment_Mid_Recovery_02.pdf',
#  'structure.php',
#  'meyd-809-en.srt',
#  'FC5B9E99-520C-4576-B0C3-7C3F8391BBC4.png',
#  'WhatsApp Video 2025-03-08 at 00.22.30.mp4',
#  'MId assignment.zip',
#  'rar 3',
#  '490095354_9843838298970750_1622483236912567316_n.mp4',
#  'Pptx',
#  'WhatsApp Video 2025-03-08 at 00.27.04.mp4',
#  'Effective_Waste_Management_Bangladesh_Assignment.docx',
#  'FB_IMG_1741957480363.jpg',
#  'e9635ef9-a953-43e2-94cd-4057e0569a29.jpg',
#  'Luffy Gear 5 na lua.jpeg',
#  'DSA_1_ProblemSet_Searching.pdf',
#  'functional_dependency.pptx',
#  'CSE 1326 Exp 2.pptx',
#  'Physics L-123.pdf',
#  'Cover_Page__Assignment_2183_R.pdf',
#  'WhatsApp Video 2025-12-30 at 17.14.03.mp4',
#  'WhatsApp Image 2024-12-12 at 11.03.41.jpeg',
#  'DSA_1_ProblemSet_Sorting.pdf',
#  'DLD',
#  'python codes',
#  'C5275D08-6D64-44D9-AE0E-8FB246F5EB6D.png',
#  'ADN-609 HD - Waka Misono.ja-en.srt',
#  'SPL_M_V_Final_Assignment.pdf',
#  '491480152_9496132710423358_4768200210579069408_n.mp4',
#  'MEYD-890.en.whisperjav-en.srt',
#  'ass',
#  'Zoom.pkg',
#  'OOP assignment',
#  'Man vs Wild',
#  'WhatsApp Video 2025-03-08 at 00.22.22.mp4',
#  'Discrete Math',
#  '04. Decoders.pptx',
#  '~$Artificial Intelligence–Grounded Fake News Sensor.pptx',
#  'K-map and simplification (1).ppt',
#  'Files.zip',
#  'Exam Routine_files',
#  '0112410214',
#  'Online Examination System ER diagram.png',
#  'mysql-8.0.44-macos15-arm64.dmg',
#  'CSE 1326 Exp 5.pptx',
#  'EC Assignment solved.pdf',
#  'physics',
#  '491511585_29104030089240945_1089342464866340327_n.mp4',
#  '~$D lab report Counter.docx',
#  'Binomial,Poission, Normal Distribution.pdf',
#  'DLD Theory',
#  '491493170_24123261643942144_805141433646321995_n.mp4',
#  '2BDC3B16-4E72-47E5-8847-9D38F1D7AB35.png',
#  '~$titled document (1).docx',
#  '4.Estimation and Hypothesis).pdf',
#  'Photos',
#  'Assignment & solve',
#  'fundamental-of-electric-circuits-5th-edition.pdf',
#  '02. Simple-minimize-functions.pptx',
#  'K-map and simplification.ppt',
#  'Untitled design (1).png',
#  'wallpaperflare.com_wallpaper (6).jpg',
#  'GUI_practice.pdf',
#  'Assignment_Question_1_242_CSE_1112_M_V (1).pdf',
#  '03-structure.pptx.pdf',
#  '491501526_9372578392841398_1950838807496978104_n.mp4',
#  'mysql-workbench-community-8.0.45-macos-arm64.dmg',
#  '03. Full-adder.pptx',
#  'Math-2183_Course_Syllabus_Fall_24 (ShIA).pdf',
#  'CSE 1326 Exp 1 (1).pptx',
#  'Assigment BMT-2.pdf',
#  'Stats',
#  'dld note.pdf',
#  '0112410205-C-Spring 25.pdf',
#  'Electronics report-2.pdf',
#  'VSCode-darwin-universal.zip',
#  'Chief.of.War.S01E02.1080p.10bit.WEBRip.6CH.x265.HEVC-PSA.mkv',
#  '~$tahmid.docx',
#  'Complete-Python-3-Bootcamp-master.zip',
#  '1325915.png',
#  'Diode_updated.pptx',
#  'CSE 1326 Exp 4.pptx',
#  '01. Logic-gates.pptx',
#  'Cv.pdf',
#  '3. Discrete, continuous, expectations.pdf',
#  '18082fe970810f0a0aae68454e854ef4.jpg',
#  'Presentation 2.pdf',
#  'Lulu-ENG-en.srt']

# %% [markdown]
# ### Moving Files
#
# You can use the built-in **shutil** module to to move files to different locations. Keep in mind, there are permission restrictions, for example if you are logged in a User A, you won't be able to make changes to the top level Users folder without the proper permissions, [more info](https://stackoverflow.com/questions/23253439/shutil-movescr-dst-gets-me-ioerror-errno-13-permission-denied-and-3-more-e)

# %%
import shutil

# %%
shutil.move('practice.txt','/Users/mitul/Downloads')
# Out:
# '/Users/mitul/Downloads/practice.txt'

# %%
os.listdir()
# Out:
# ['Example_Top_Level',
#  '08-Advanced-Python-Module-Exercise',
#  '00-Collections-Module.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '02-Datetime-Module.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '.ipynb_checkpoints',
#  '04-Python Debugger (pdb).ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb']

# %%
shutil.move('/Users/mitul/Downloads/practice.txt',os.getcwd())
# Out:
# '/Users/mitul/Downloads/Complete-Python-3-Bootcamp-master/12-Advanced Python Modules/practice.txt'

# %%
os.listdir()
# Out:
# ['Example_Top_Level',
#  '08-Advanced-Python-Module-Exercise',
#  'practice.txt',
#  '00-Collections-Module.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '02-Datetime-Module.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '.ipynb_checkpoints',
#  '04-Python Debugger (pdb).ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb']

# %% [markdown]
# ### Deleting Files
# ____
# **NOTE: The os module provides 3 methods for deleting files:**
# * os.unlink(path) which deletes a file at the path your provide
# * os.rmdir(path) which deletes a folder (folder must be empty) at the path your provide
# * shutil.rmtree(path) this is the most dangerous, as it will remove all files and folders contained in the path.
# **All of these methods can not be reversed! Which means if you make a mistake you won't be able to recover the file. Instead we will use the send2trash module. A safer alternative that sends deleted files to the trash bin instead of permanent removal.**
# ___
#
# Install the send2trash module with:
#
#     pip install send2trash
#
# at your command line.

# %%
import send2trash
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import send2trash
#
# ModuleNotFoundError: No module named 'send2trash'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Datetime-Module.ipynb',
#  '01-Opening-and-Reading-Files.ipynb',
#  '02-Math-and-Random-Module.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '04-Timing your code - timeit.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Unzipping-and-Zipping-Files.ipynb',
#  '07-OS-Module.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'Example_Top_Level',
#  'extracted_content',
#  'new_file.txt',
#  'new_file2.txt',
#  'practice.txt']

# %%
send2trash.send2trash('practice.txt')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Datetime-Module.ipynb',
#  '01-Opening-and-Reading-Files.ipynb',
#  '02-Math-and-Random-Module.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '04-Timing your code - timeit.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Unzipping-and-Zipping-Files.ipynb',
#  '07-OS-Module.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'Example_Top_Level',
#  'extracted_content',
#  'new_file.txt',
#  'new_file2.txt']

# %% [markdown]
# ### Walking through a directory
#
# Often you will just need to "walk" through a directory, that is visit every file or folder and check to see if a file is in the directory, and then perhaps do something with that file. Usually recursively walking through every file and folder in a directory would be quite tricky to program, but luckily the os module has a direct method call for this called os.walk(). Let's explore how it works.

# %%
os.getcwd()
# Out:
# '/Users/mitul/Downloads/Complete-Python-3-Bootcamp-master/12-Advanced Python Modules'

# %%
os.listdir()
# Out:
# ['Example_Top_Level',
#  '08-Advanced-Python-Module-Exercise',
#  'practice.txt',
#  '00-Collections-Module.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '02-Datetime-Module.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '.ipynb_checkpoints',
#  'venv',
#  '04-Python Debugger (pdb).ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb']

# %%
for folder , sub_folders , files in os.walk("Example_Top_Level"):
    
    print("Currently looking at folder: "+ folder)
    print('\n')
    print("THE SUBFOLDERS ARE: ")
    for sub_fold in sub_folders:
        print("\t Subfolder: "+sub_fold )
    
    print('\n')
    
    print("THE FILES ARE: ")
    for f in files:
        print("\t File: "+f)
    print('\n')
    
    # Now look at subfolders
# Out:
# Currently looking at folder: Example_Top_Level
#
#
# THE SUBFOLDERS ARE:
# 	 Subfolder: Mid-Example-One
#
#
# THE FILES ARE:
# 	 File: Mid-Example.txt
#
#
# Currently looking at folder: Example_Top_Level/Mid-Example-One
#
#
# THE SUBFOLDERS ARE:
# 	 Subfolder: Bottom-Level-Two
# 	 Subfolder: Bottom-Level-One
#
#
# THE FILES ARE:
# 	 File: Mid-Level-Doc.txt
#
#
# Currently looking at folder: Example_Top_Level/Mid-Example-One/Bottom-Level-Two
#
#
# THE SUBFOLDERS ARE:
#
#
# THE FILES ARE:
# 	 File: Bottom-Text-Two.txt
#
#
# Currently looking at folder: Example_Top_Level/Mid-Example-One/Bottom-Level-One
#
#
# THE SUBFOLDERS ARE:
#
#
# THE FILES ARE:
# 	 File: One_Text.txt

# %% [markdown]
# ___
# Excellent, you should now be aware of how to work with a computer's files and folders in whichever directory they are in. Remember that the os module works for any oeprating system that supports Python, which means these commands will work across Linux,MacOs, or Windows without need for adjustment.
