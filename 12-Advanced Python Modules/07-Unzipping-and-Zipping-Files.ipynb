# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Unzipping and Zipping Files
#
# As you are probably aware, files can be compressed to a zip format. Often people use special programs on their computer to unzip these files, luckily for us, Python can do the same task with just a few simple lines of code.

# %% [markdown]
# ## Create Files to Compress

# %%
# slashes may need to change for MacOS or Linux
f = open("new_file.txt",'w+')
f.write("Here is some text")
f.close()

# %%
f=open('My_file.txt','w+')
f.write('Amar sonar bangla')
f.close()

# %%
# slashes may need to change for MacOS or Linux
f = open("new_file2.txt",'w+')
f.write("Here is some text")
f.close()

# %% [markdown]
# ## Zipping Files
#
# The [zipfile library](https://docs.python.org/3/library/zipfile.html) is built in to Python, we can use it to compress folders or files. To compress all files in a folder, just use the os.walk() method to iterate this process for all the files in a directory.

# %%
import zipfile

# %% [markdown]
#  Create Zip file first , then write to it (the write step compresses the files.)

# %%
z_file=zipfile.ZipFile('My_zipfile.zip','w')

# %%
z_file.write("My_file.txt",compress_type=zipfile.ZIP_DEFLATED)
z_file.close()

# %%
comp_file = zipfile.ZipFile('comp_file.zip','w')

# %%
comp_file.write("new_file.txt",compress_type=zipfile.ZIP_DEFLATED)

# %%
comp_file.write('new_file2.txt',compress_type=zipfile.ZIP_DEFLATED)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 comp_file.write('new_file2.txt',compress_type=zipfile.ZIP_DEFLATED)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/zipfile/__init__.py:1968, in ZipFile.write(self, filename, arcname, compress_type, compresslevel)
#    1963 if self._writing:
#    1964     raise ValueError(
#    1965         "Can't write to ZIP archive while an open writing handle exists"
#    1966     )
# -> 1968 zinfo = ZipInfo.from_file(filename, arcname,
#    1969                           strict_timestamps=self._strict_timestamps)
#    1971 if zinfo.is_dir():
#    1972     zinfo.compress_size = 0
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/zipfile/__init__.py:631, in ZipInfo.from_file(cls, filename, arcname, strict_timestamps)
#     629 if isinstance(filename, os.PathLike):
#     630     filename = os.fspath(filename)
# --> 631 st = os.stat(filename)
#     632 isdir = stat.S_ISDIR(st.st_mode)
#     633 mtime = time.localtime(st.st_mtime)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'new_file2.txt'

# %%
comp_file.close()

# %% [markdown]
# ## Extracting from Zip Files
#
# We can easily extract files with either the extractall() method to get all the files, or just using the extract() method to only grab individual files.

# %%
zip_ext=zipfile.ZipFile('My_zipfile.zip','r') #using created object of zip file in the braket to extract.

# %%
zip_obj = zipfile.ZipFile('comp_file.zip','r')

# %%
zip_obj.extractall("extracted_content")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 zip_obj.extractall("extracted_content")
#
# NameError: name 'zip_obj' is not defined

# %% [markdown]
# ________

# %% [markdown]
# # Using shutil library
#
# Often you don't want to extract or archive individual files from a .zip, but instead archive everything at once. The shutil library that is built in to python has easy to use commands for this:

# %%
import shutil

# %% [markdown]
# The shutil library can accept a format parameter, `format` is the archive format: one of "zip", "tar", "gztar", "bztar",
# or "xztar".

# %%
pwd
# Out:
# '/Users/mitul/Downloads/Complete-Python-3-Bootcamp-master/12-Advanced Python Modules'

# %%
directory_to_zip='/Users/mitul/Downloads/Complete-Python-3-Bootcamp-master/12-Advanced Python Modules/shutil_extract'

# %%
output_file='shutil_file'
shutil.make_archive(output_file,'zip',directory_to_zip)
# Out:
# '/Users/mitul/Downloads/Complete-Python-3-Bootcamp-master/12-Advanced Python Modules/shutil_file.zip'

# %%
shutil.unpack_archive('output_file','shutil_unzip','zip')

# %%
# Creating a zip archive
output_filename = 'example'
# Just fill in the output_filename and the directory to zip
# Note this won't run as is because the variable are undefined
shutil.make_archive(output_filename,'zip',directory_to_zip)
# Out:
# '/Users/mitul/Downloads/Complete-Python-3-Bootcamp-master/12-Advanced Python Modules/example.zip'

# %%
# Creating a zip archive
output_filename = 'example'
shutil.make_archive(output_filename,'zip',directory_to_zip)

# Extracting a zip archive
# Notice how the parameter/argument order is slightly different here
dir_for_extract_result = '/Users/mitul/Downloads/Complete-Python-3-Bootcamp-master/12-Advanced Python Modules/shutil_extract' # Change to your desired path
shutil.unpack_archive(output_filename + '.zip', dir_for_extract_result, 'zip')
# Out:
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# Cell In[30], line 8
#       5 # Extracting a zip archive
#       6 # Notice how the parameter/argument order is slightly different here
#       7 dir_for_extract_result = '/Users/mitul/Downloads/Complete-Python-3-Bootcamp-master/12-Advanced Python Modules/shutil_extract' # Change to your desired path
# ----> 8 shutil.unpack_archive(output_filename,dir_for_extract_result,'zip')
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/shutil.py:1423, in unpack_archive(filename, extract_dir, format, filter)
#    1420         raise ValueError("Unknown unpack format '{0}'".format(format)) from None
#    1422     func = format_info[1]
# -> 1423     func(filename, extract_dir, **dict(format_info[2]), **filter_kwargs)
#    1424 else:
#    1425     # we need to look at the registered unpackers supported extensions
#    1426     format = _find_unpack_format(filename)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/shutil.py:1315, in _unpack_zipfile(filename, extract_dir)
#    1312 import zipfile  # late import for breaking circular dependency
#    1314 if not zipfile.is_zipfile(filename):
# -> 1315     raise ReadError("%s is not a zip file" % filename)
#    1317 zip = zipfile.ZipFile(filename)
#    1318 try:
#
# ReadError: example is not a zip file
